# %%
# Import the pathlib and csv library
from pathlib import Path
import csv

# Set the file path
csvpath = Path('../../Resources/budget_data.csv')

# Initialize list of records
records = []
total_months = 0
total_profits = 0
minimum = 0
maximum = 0
previous_monthly_profit = None
monthly_profit_change = 0
total_monthly_profit_change = 0
minimumdate = 0
maximumdate = 0

# Open the csv file as an object
with open(csvpath, 'r') as csvfile:

    # What's the header
    csvreader = csv.reader(csvfile, delimiter=',')
    csv_header = next(csvreader)
    
    # Read each row of data after header
    for row in csvreader:
        # Print(row)
        
    # Count number of months
        total_months += 1
    
    # Calculate net profit and losses
        monthly_profit_losses = int(row[1])
        Date = row[0]      
        total_profits += monthly_profit_losses
        
    # Calculate monthly profit/losses change
        if previous_monthly_profit is None:
            previous_monthly_profit = monthly_profit_losses
            # print("First row")
            # print(f"previous_monthly_profit = {previous_monthly_profit}")
        else:
            #We are not on the first row
            # Print("Other rows")
            # Print(f"previous_monthly_profit = {previous_monthly_profit}")
            monthly_profit_change = monthly_profit_losses - previous_monthly_profit
            previous_monthly_profit = monthly_profit_losses
    
     # The greatest increase in profits (date and amount) over the entire period
        if minimum == 0:
            minimum = monthly_profit_change
            minimumdate = Date
        elif monthly_profit_change < minimum:
            minimum = monthly_profit_change
            minimumdate = Date
        elif monthly_profit_change > maximum:
            maximum = monthly_profit_change
            maximumdate = Date
            
     # The greatest decreasein losses (date and amount) over the entire period.
        
        
        total_monthly_profit_change += monthly_profit_change
            
# Average P/L
averagePnl = round(total_profits / total_months, 2)

#Average monthly profit change
average_monthly_profit_change = round(total_monthly_profit_change / (total_months - 1), 2)

# Open CSV file
with open(csvpath, 'r') as csvfile:
    
        # What's the header
        csvreader = csv.reader(csvfile, delimiter = ',')
        csv_header = next(csvreader)
        #csv_header.append("NewCol")
        records.append(csv_header)
        
        # Read each row of data after header
        
   
   
        
        
# Print results
print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {total_months}")
print(f"Total: ${total_profits}")
print(f"Average Change: ${average_monthly_profit_change}")
print(f"Greatest Increase in Profits: {maximumdate} (${maximum})")
print(f"Greatest Decrease in Losses: {minimumdate} (${minimum})")
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1926159)
# Greatest Decrease in Losses: Sep-2013 ($-2196167)
